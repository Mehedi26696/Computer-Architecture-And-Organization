# %% [markdown]
# # 🧠 CPU Organization – Notes
#
# ---
#
# ## 1. Introduction
# - **CPU (Central Processing Unit)** is the brain of the computer.
# - It performs all arithmetic and logical operations and controls all components.
# - Also called **Processor** or **Microprocessor** in microcomputers.
#
# ---
#
# ## 2. Major Components of CPU
#
# | Component        | Description |
# |------------------|-------------|
# | **ALU** (Arithmetic Logic Unit) | Performs arithmetic (add, subtract) and logic operations (AND, OR, NOT). |
# | **CU** (Control Unit)           | Directs operations of the processor. It tells memory, ALU, and I/O devices how to respond to instructions. |
# | **Registers**                  | Small, fast memory units inside the CPU. Used to store intermediate data, instructions, addresses. |
#
# ---
#
# ## 3. Types of Registers
# - **MAR (Memory Address Register)** – Holds address of memory location.
# - **MDR (Memory Data Register)** – Holds data being transferred to/from memory.
# - **IR (Instruction Register)** – Holds the current instruction.
# - **PC (Program Counter)** – Holds address of next instruction.
# - **ACC (Accumulator)** – Stores intermediate results from ALU.
# - **General Purpose Registers (R0–Rn)** – Used for general computations.
#
# ---
#
# ## 4. CPU Buses
# - **Data Bus** – Carries data (bi-directional).
# - **Address Bus** – Carries address to memory (uni-directional).
# - **Control Bus** – Carries control signals (read/write).
#
# ---
#
# ## 5. Instruction Cycle (Fetch-Decode-Execute Cycle)
# 1. **Fetch** – Instruction is fetched from memory using PC.
# 2. **Decode** – Control Unit decodes the instruction.
# 3. **Execute** – ALU or other components perform the operation.
#
# ---
#
# ## 6. CPU Types
# - **CISC (Complex Instruction Set Computer)** – Many complex instructions; fewer instructions per program.
# - **RISC (Reduced Instruction Set Computer)** – Fewer instructions; simpler; faster per instruction.
# - **Superscalar CPU** – Executes more than one instruction per cycle.
# - **Multicore CPU** – Multiple processing units on a single chip.
#
# ---
#
# ## 7. Control Unit Types
# - **Hardwired Control Unit**: Uses fixed logic circuits; faster but inflexible.
# - **Microprogrammed Control Unit**: Uses control memory; flexible and easier to modify.
#
# ---
#
# ## 8. Performance Factors
# - **Clock Speed** – Number of cycles per second (Hz).
# - **Instruction Per Cycle (IPC)** – Efficiency of execution.
# - **Pipelining** – Improves performance by overlapping instruction stages.
# - **Cache Memory** – Small high-speed memory to reduce access time to frequently used data.
#
# ---
#
# ## 9. Pipelining
# - Technique for executing multiple instructions in overlapping stages:
#   - **Stages**: Fetch → Decode → Execute → Memory → Write Back
# - **Hazards**:
#   - **Data Hazard** – Instruction depends on result of previous.
#   - **Control Hazard** – Due to branching.
#   - **Structural Hazard** – Hardware resources conflict.
#
# ---
#
# ## 10. Modern Enhancements
# - **Out-of-Order Execution**
# - **Branch Prediction**
# - **Speculative Execution**
# - **Hyper-Threading (Simultaneous Multi-threading)**
#
# ---
#
# *Let me know if you want diagrams, interactive visuals, or a quiz to practice this content!*
